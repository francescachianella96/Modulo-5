# %%
# !pip install keras_cv
# Out:
# Collecting keras_cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from keras_cv) (26.2)
# Requirement already satisfied: absl-py in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from keras_cv) (2.4.0)
# Collecting regex (from keras_cv)
#   Downloading regex-2026.6.28-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tensorflow-datasets (from keras_cv)
#   Downloading tensorflow_datasets-4.9.10-py3-none-any.whl.metadata (11 kB)
# Collecting keras-core (from keras_cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Collecting kagglehub (from keras_cv)
#   Downloading kagglehub-1.0.2-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub->keras_cv)
#   Downloading kagglesdk-0.1.30-py3-none-any.whl.metadata (13 kB)
# Collecting pyyaml (from kagglehub->keras_cv)
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: requests in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from kagglehub->keras_cv) (2.34.2)
# Collecting tqdm (from kagglehub->keras_cv)
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: protobuf in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub->keras_cv) (7.35.1)
# Requirement already satisfied: numpy in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from keras-core->keras_cv) (2.4.6)
# Requirement already satisfied: rich in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from keras-core->keras_cv) (15.0.0)
# Requirement already satisfied: namex in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from keras-core->keras_cv) (0.1.0)
# Requirement already satisfied: h5py in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from keras-core->keras_cv) (3.14.0)
# Collecting dm-tree (from keras-core->keras_cv)
#   Downloading dm_tree-0.1.10-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting attrs>=18.2.0 (from dm-tree->keras-core->keras_cv)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: wrapt>=1.11.2 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from dm-tree->keras-core->keras_cv) (2.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests->kagglehub->keras_cv) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests->kagglehub->keras_cv) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests->kagglehub->keras_cv) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests->kagglehub->keras_cv) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from rich->keras-core->keras_cv) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from rich->keras-core->keras_cv) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)
# Collecting etils>=1.9.1 (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv)
#   Downloading etils-1.14.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting immutabledict (from tensorflow-datasets->keras_cv)
#   Downloading immutabledict-4.3.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting promise (from tensorflow-datasets->keras_cv)
#   Downloading promise-2.3.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: psutil in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from tensorflow-datasets->keras_cv) (7.2.2)
# Collecting pyarrow (from tensorflow-datasets->keras_cv)
#   Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Collecting simple_parsing (from tensorflow-datasets->keras_cv)
#   Downloading simple_parsing-0.1.8-py3-none-any.whl.metadata (8.1 kB)
# Collecting tensorflow-metadata (from tensorflow-datasets->keras_cv)
#   Downloading tensorflow_metadata-1.21.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: termcolor in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from tensorflow-datasets->keras_cv) (3.3.0)
# Collecting toml (from tensorflow-datasets->keras_cv)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting einops (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv)
#   Downloading einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: fsspec in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (2026.6.0)
# Requirement already satisfied: typing_extensions in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv) (4.15.0)
# Collecting zipp (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras_cv)
#   Downloading zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: six in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from promise->tensorflow-datasets->keras_cv) (1.17.0)
# Collecting docstring-parser~=0.15 (from simple_parsing->tensorflow-datasets->keras_cv)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting googleapis-common-protos<2,>=1.56.4 (from tensorflow-metadata->tensorflow-datasets->keras_cv)
#   Downloading googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from tqdm->kagglehub->keras_cv) (0.4.6)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ---------------------------------------- 0.0/650.7 kB ? eta -:--:--
#    ---------------------------------------- 650.7/650.7 kB 12.1 MB/s  0:00:00
# Downloading kagglehub-1.0.2-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.30-py3-none-any.whl (231 kB)
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ---------------------------------------- 0.0/950.8 kB ? eta -:--:--
#    ---------------------------------------- 950.8/950.8 kB 43.0 MB/s  0:00:00
# Downloading dm_tree-0.1.10-cp311-cp311-win_amd64.whl (111 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Downloading regex-2026.6.28-cp311-cp311-win_amd64.whl (277 kB)
# Downloading tensorflow_datasets-4.9.10-py3-none-any.whl (5.3 MB)
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ---------------------------------------- 5.3/5.3 MB 54.0 MB/s  0:00:00
# Downloading etils-1.14.0-py3-none-any.whl (172 kB)
# Downloading einops-0.8.2-py3-none-any.whl (65 kB)
# Downloading immutabledict-4.3.1-py3-none-any.whl (5.0 kB)
# Downloading pyarrow-24.0.0-cp311-cp311-win_amd64.whl (27.3 MB)
#    ---------------------------------------- 0.0/27.3 MB ? eta -:--:--
#    ----------------- ---------------------- 12.1/27.3 MB 58.1 MB/s eta 0:00:01
#    ------------------------------------- -- 25.4/27.3 MB 62.0 MB/s eta 0:00:01
#    ---------------------------------------- 27.3/27.3 MB 55.8 MB/s  0:00:00
# Downloading simple_parsing-0.1.8-py3-none-any.whl (113 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading tensorflow_metadata-1.21.0-py3-none-any.whl (30 kB)
# Downloading googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
# Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Building wheels for collected packages: promise
#   Building wheel for promise (pyproject.toml): started
#   Building wheel for promise (pyproject.toml): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21643 sha256=522e9edb933881887ec6dedc806730417e37f77f2cf3ea629b5703472e7650ac
#   Stored in directory: c:\users\chian\appdata\local\pip\cache\wheels\90\74\b1\9b54c896b8d9409e9268329d4d45ede8a8040abe91c8879932
# Successfully built promise
# Installing collected packages: zipp, tqdm, toml, regex, pyyaml, pyarrow, promise, immutabledict, googleapis-common-protos, etils, einops, docstring-parser, attrs, tensorflow-metadata, simple_parsing, kagglesdk, dm-tree, keras-core, kagglehub, tensorflow-datasets, keras_cv
#
#    ----- ----------------------------------  3/21 [regex]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------- ------------------------------  5/21 [pyarrow]
#    --------------- ------------------------  8/21 [googleapis-common-protos]
#    ----------------- ----------------------  9/21 [etils]
#    ----------------- ----------------------  9/21 [etils]
#    -------------------- ------------------- 11/21 [docstring-parser]
#    -------------------------- ------------- 14/21 [simple_parsing]
#    ---------------------------- ----------- 15/21 [kagglesdk]
#    ---------------------------- ----------- 15/21 [kagglesdk]
#    ---------------------------- ----------- 15/21 [kagglesdk]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    -------------------------------- ------- 17/21 [keras-core]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    ------------------------------------ --- 19/21 [tensorflow-datasets]
#    -------------------------------------- - 20/21 [keras_cv]
#    -------------------------------------- - 20/21 [keras_cv]
#    -------------------------------------- - 20/21 [keras_cv]
#    -------------------------------------- - 20/21 [keras_cv]
#    -------------------------------------- - 20/21 [keras_cv]
#    -------------------------------------- - 20/21 [keras_cv]
#    ---------------------------------------- 21/21 [keras_cv]
#
# Successfully installed attrs-26.1.0 dm-tree-0.1.10 docstring-parser-0.18.0 einops-0.8.2 etils-1.14.0 googleapis-common-protos-1.75.0 immutabledict-4.3.1 kagglehub-1.0.2 kagglesdk-0.1.30 keras-core-0.1.7 keras_cv-0.9.0 promise-2.3 pyarrow-24.0.0 pyyaml-6.0.3 regex-2026.6.28 simple_parsing-0.1.8 tensorflow-datasets-4.9.10 tensorflow-metadata-1.21.0 toml-0.10.2 tqdm-4.68.3 zipp-4.1.0

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.82-py3-none-any.whl.metadata (41 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (2.4.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (3.11.0)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (2.12.1)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.27.1-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: psutil>=5.8.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.42.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.42.0 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.42.0-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: filelock in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from torch>=1.8.0->ultralytics) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.82-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.3 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 9.8 MB/s  0:00:00
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/40.2 MB 13.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.5/40.2 MB 12.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.0/40.2 MB 9.2 MB/s eta 0:00:04
#    -------- ------------------------------- 8.4/40.2 MB 9.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 17.8/40.2 MB 17.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 28.6/40.2 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------  39.6/40.2 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 26.4 MB/s  0:00:01
# Downloading polars-1.42.0-py3-none-any.whl (836 kB)
#    ---------------------------------------- 0.0/836.9 kB ? eta -:--:--
#    ---------------------------------------- 836.9/836.9 kB 35.9 MB/s  0:00:00
# Downloading polars_runtime_32-1.42.0-cp310-abi3-win_amd64.whl (52.7 MB)
#    ---------------------------------------- 0.0/52.7 MB ? eta -:--:--
#    ------ --------------------------------- 8.1/52.7 MB 41.8 MB/s eta 0:00:02
#    ------------- -------------------------- 18.4/52.7 MB 46.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 29.9/52.7 MB 48.6 MB/s eta 0:00:01
#    ------------------------------ --------- 40.6/52.7 MB 49.7 MB/s eta 0:00:01
#    -------------------------------------- - 50.9/52.7 MB 49.8 MB/s eta 0:00:01
#    ---------------------------------------- 52.7/52.7 MB 46.6 MB/s  0:00:01
# Downloading torchvision-0.27.1-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 45.5 MB/s  0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-ml-py, polars-runtime-32, opencv-python, polars, ultralytics-thop, torchvision, ultralytics
#
#    ----- ---------------------------------- 1/7 [polars-runtime-32]
#    ----- ---------------------------------- 1/7 [polars-runtime-32]
#    ----- ---------------------------------- 1/7 [polars-runtime-32]
#    ----- ---------------------------------- 1/7 [polars-runtime-32]
#    ----------- ---------------------------- 2/7 [opencv-python]
#    ----------- ---------------------------- 2/7 [opencv-python]
#    ----------- ---------------------------- 2/7 [opencv-python]
#    ----------------- ---------------------- 3/7 [polars]
#    ----------------- ---------------------- 3/7 [polars]
#    ----------------- ---------------------- 3/7 [polars]
#    ----------------- ---------------------- 3/7 [polars]
#    ---------------------- ----------------- 4/7 [ultralytics-thop]
#    ---------------------------- ----------- 5/7 [torchvision]
#    ---------------------------- ----------- 5/7 [torchvision]
#    ---------------------------- ----------- 5/7 [torchvision]
#    ---------------------------- ----------- 5/7 [torchvision]
#    ---------------------------------- ----- 6/7 [ultralytics]
#    ---------------------------------- ----- 6/7 [ultralytics]
#    ---------------------------------- ----- 6/7 [ultralytics]
#    ---------------------------------- ----- 6/7 [ultralytics]
#    ---------------------------------- ----- 6/7 [ultralytics]
#    ---------------------------------- ----- 6/7 [ultralytics]
#    ---------------------------------------- 7/7 [ultralytics]
#
# Successfully installed nvidia-ml-py-13.610.43 opencv-python-4.13.0.92 polars-1.42.0 polars-runtime-32-1.42.0 torchvision-0.27.1 ultralytics-8.4.82 ultralytics-thop-2.0.20

# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.35-py3-none-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: absl-py~=2.3 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from mediapipe) (2.4.0)
# Requirement already satisfied: certifi in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from mediapipe) (2026.6.17)
# Requirement already satisfied: numpy in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from mediapipe) (2.4.6)
# Collecting sounddevice~=0.5 (from mediapipe)
#   Downloading sounddevice-0.5.5-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: flatbuffers~=25.9 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from mediapipe) (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from mediapipe) (3.11.0)
# Collecting cffi (from sounddevice~=0.5->mediapipe)
#   Downloading cffi-2.1.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi->sounddevice~=0.5->mediapipe)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.35-py3-none-win_amd64.whl (10.9 MB)
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/10.9 MB 8.4 MB/s eta 0:00:02
#    ---------------------------------------  10.7/10.9 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.9/10.9 MB 28.4 MB/s  0:00:00
# Downloading sounddevice-0.5.5-py3-none-win_amd64.whl (365 kB)
# Downloading cffi-2.1.0-cp311-cp311-win_amd64.whl (185 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pycparser, cffi, sounddevice, mediapipe
#
#    -------------------- ------------------- 2/4 [sounddevice]
#    ------------------------------ --------- 3/4 [mediapipe]
#    ------------------------------ --------- 3/4 [mediapipe]
#    ------------------------------ --------- 3/4 [mediapipe]
#    ---------------------------------------- 4/4 [mediapipe]
#
# Successfully installed cffi-2.1.0 mediapipe-0.10.35 pycparser-3.0 sounddevice-0.5.5

# %%
# !pip install cmake
# Out:
# Collecting cmake
#   Using cached cmake-4.3.4-py3-none-win_amd64.whl.metadata (6.5 kB)
# Using cached cmake-4.3.4-py3-none-win_amd64.whl (41.3 MB)
# Installing collected packages: cmake
# Successfully installed cmake-4.3.4

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (26.1.2)
# Requirement already satisfied: setuptools in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (65.5.0)
# Collecting setuptools
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: wheel in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (0.47.0)
# Requirement already satisfied: packaging>=24.0 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from wheel) (26.2)
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.5.0
#     Uninstalling setuptools-65.5.0:
#       Successfully uninstalled setuptools-65.5.0
# Successfully installed setuptools-83.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.12.1 requires setuptools<82, but you have setuptools 83.0.0 which is incompatible.

# %%
# !pip install dlib
# Out:
# Collecting dlib
#   Using cached dlib-20.0.1.tar.gz (3.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: dlib
#   Building wheel for dlib (pyproject.toml): started
#   Building wheel for dlib (pyproject.toml): still running...
#   Building wheel for dlib (pyproject.toml): finished with status 'done'
#   Created wheel for dlib: filename=dlib-20.0.1-cp311-cp311-win_amd64.whl size=2766265 sha256=20e3cb385bd176189216aa9cb9fe78d1c5a10f42fcc4fa17685ed215a15b8fcc
#   Stored in directory: c:\users\chian\appdata\local\pip\cache\wheels\56\a8\fe\cdaa347540c83e794da01a64cf2d3b26b86effba19deb2e24d
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-20.0.1

# %%
# !pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Collecting Click>=6.0 (from face_recognition)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: dlib>=19.7 in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from face_recognition) (20.0.1)
# Requirement already satisfied: numpy in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from face_recognition) (2.4.6)
# Requirement already satisfied: Pillow in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from face_recognition) (12.2.0)
# Requirement already satisfied: colorama in c:\Users\chian\Desktop\Programmi Python\Modulo-5\.venv\Lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Installing collected packages: face-recognition-models, Click, face_recognition
#
#    ---------------------------------------- 0/3 [face-recognition-models]
#    ---------------------------------------- 0/3 [face-recognition-models]
#    ---------------------------------------- 0/3 [face-recognition-models]
#    ---------------------------------------- 3/3 [face_recognition]
#
# Successfully installed Click-8.4.2 face-recognition-models-0.3.0 face_recognition-1.3.0
